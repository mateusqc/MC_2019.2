# %%
# Biblioteca científica
import numpy as np
# Biblioteca para análise de dados
import pandas as pd
# Suprimindo os warnings da biblioteca pandas
pd.options.mode.chained_assignment = None
# Bibliotecas de visualização de dados
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.ticker as mtick
plt.style.use('ggplot')
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
# Carregando os dados
dados_hm = pd.read_csv('output/hashmapLS_data.csv', sep=' ', low_memory=False)
dados_hmls = pd.read_csv('output/hashmap_data.csv', sep=' ', low_memory=False)

# %%
dados_hm
# Out:
#               test_name  total_test_iteration  time_per_op time_per_op_un  \
# 0   BenchmarkHashMapLS1                500000         2589          ns/op
# 1   BenchmarkHashMapLS1                500000         2625          ns/op
# 2   BenchmarkHashMapLS1                500000         2528          ns/op
# 3   BenchmarkHashMapLS1                500000         2600          ns/op
# 4   BenchmarkHashMapLS1                500000         2611          ns/op
# 5   BenchmarkHashMapLS1                500000         2590          ns/op
# 6   BenchmarkHashMapLS1                500000         2520          ns/op
# 7   BenchmarkHashMapLS1                500000         2542          ns/op
# 8   BenchmarkHashMapLS1                500000         2508          ns/op
# 9   BenchmarkHashMapLS1                500000         2598          ns/op
# 10  BenchmarkHashMapLS1                500000         2472          ns/op
# 11  BenchmarkHashMapLS1                500000         2542          ns/op
# 12  BenchmarkHashMapLS1                500000         2664          ns/op
# 13  BenchmarkHashMapLS1                500000         2570          ns/op
# 14  BenchmarkHashMapLS1                500000         2599          ns/op
# 15  BenchmarkHashMapLS1                500000         2509          ns/op
# 16  BenchmarkHashMapLS1                500000         2607          ns/op
# 17  BenchmarkHashMapLS1                500000         2619          ns/op
# 18  BenchmarkHashMapLS1                500000         2642          ns/op
# 19  BenchmarkHashMapLS1                500000         2614          ns/op
# 20  BenchmarkHashMapLS1                500000         2653          ns/op
# 21  BenchmarkHashMapLS1                500000         2559          ns/op
# 22  BenchmarkHashMapLS1                500000         2690          ns/op
# 23  BenchmarkHashMapLS1                500000         2614          ns/op
# 24  BenchmarkHashMapLS1                500000         2664          ns/op
# 25  BenchmarkHashMapLS1                500000         2656          ns/op
# 26  BenchmarkHashMapLS1                500000         2546          ns/op
# 27  BenchmarkHashMapLS1                500000         2640          ns/op
# 28  BenchmarkHashMapLS1                500000         2639          ns/op
# 29  BenchmarkHashMapLS1                500000         2694          ns/op
# 30  BenchmarkHashMapLS1                500000         2639          ns/op
# 31  BenchmarkHashMapLS1                500000         2688          ns/op
# 32  BenchmarkHashMapLS1                500000         2631          ns/op
# 33  BenchmarkHashMapLS1                500000         2743          ns/op
# 34  BenchmarkHashMapLS1                500000         2669          ns/op
# 35  BenchmarkHashMapLS1                500000         2670          ns/op
# 36  BenchmarkHashMapLS1                500000         2699          ns/op
# 37  BenchmarkHashMapLS1                500000         2652          ns/op
# 38  BenchmarkHashMapLS1                500000         2676          ns/op
# 39  BenchmarkHashMapLS1                500000         2713          ns/op
# 40  BenchmarkHashMapLS1                500000         2756          ns/op
# 41  BenchmarkHashMapLS1                500000         2596          ns/op
# 42  BenchmarkHashMapLS1                500000         2740          ns/op
# 43  BenchmarkHashMapLS1                500000         2851          ns/op
#
#     size_per_op size_per_op_un  allocs_per_op allocs_per_op_un flag1  \
# 0           251           B/op              4        allocs/op    ok
# 1           254           B/op              4        allocs/op    ok
# 2           248           B/op              4        allocs/op    ok
# 3           252           B/op              4        allocs/op    ok
# 4           251           B/op              4        allocs/op    ok
# 5           247           B/op              4        allocs/op    ok
# 6           250           B/op              4        allocs/op    ok
# 7           258           B/op              4        allocs/op    ok
# 8           252           B/op              4        allocs/op    ok
# 9           253           B/op              4        allocs/op    ok
# 10          248           B/op              4        allocs/op    ok
# 11          266           B/op              5        allocs/op    ok
# 12          263           B/op              5        allocs/op    ok
# 13          262           B/op              5        allocs/op    ok
# 14          264           B/op              5        allocs/op    ok
# 15          256           B/op              5        allocs/op    ok
# 16          261           B/op              5        allocs/op    ok
# 17          259           B/op              5        allocs/op    ok
# 18          262           B/op              5        allocs/op    ok
# 19          260           B/op              5        allocs/op    ok
# 20          265           B/op              5        allocs/op    ok
# 21          267           B/op              5        allocs/op    ok
# 22          261           B/op              6        allocs/op    ok
# 23          261           B/op              6        allocs/op    ok
# 24          263           B/op              6        allocs/op    ok
# 25          257           B/op              6        allocs/op    ok
# 26          266           B/op              6        allocs/op    ok
# 27          258           B/op              6        allocs/op    ok
# 28          267           B/op              6        allocs/op    ok
# 29          259           B/op              6        allocs/op    ok
# 30          261           B/op              6        allocs/op    ok
# 31          264           B/op              6        allocs/op    ok
# 32          264           B/op              6        allocs/op    ok
# 33          268           B/op              6        allocs/op    ok
# 34          316           B/op              6        allocs/op    ok
# 35          270           B/op              6        allocs/op    ok
# 36          272           B/op              6        allocs/op    ok
# 37          267           B/op              6        allocs/op    ok
# 38          269           B/op              6        allocs/op    ok
# 39          267           B/op              6        allocs/op    ok
# 40          274           B/op              6        allocs/op    ok
# 41          270           B/op              6        allocs/op    ok
# 42          265           B/op              6        allocs/op    ok
# 43          318           B/op              6        allocs/op    ok
#
#                      flag2 exec_time     num
# 0   command-line-arguments    2.211s     100
# 1   command-line-arguments    2.271s     100
# 2   command-line-arguments    2.211s     100
# 3   command-line-arguments    2.237s     100
# 4   command-line-arguments    2.291s     100
# 5   command-line-arguments    2.259s     100
# 6   command-line-arguments    2.196s     100
# 7   command-line-arguments    2.202s     100
# 8   command-line-arguments    2.177s     100
# 9   command-line-arguments    2.255s     100
# 10  command-line-arguments    2.149s     100
# 11  command-line-arguments    2.211s    1000
# 12  command-line-arguments    2.296s    1000
# 13  command-line-arguments    2.264s    1000
# 14  command-line-arguments    2.272s    1000
# 15  command-line-arguments    2.204s    1000
# 16  command-line-arguments    2.243s    1000
# 17  command-line-arguments    2.266s    1000
# 18  command-line-arguments    2.289s    1000
# 19  command-line-arguments    2.275s    1000
# 20  command-line-arguments    2.262s    1000
# 21  command-line-arguments    2.219s    1000
# 22  command-line-arguments    2.334s   10000
# 23  command-line-arguments    2.283s   10000
# 24  command-line-arguments    2.324s   10000
# 25  command-line-arguments    2.310s   10000
# 26  command-line-arguments    2.260s   10000
# 27  command-line-arguments    2.286s   10000
# 28  command-line-arguments    2.329s   10000
# 29  command-line-arguments    2.354s   10000
# 30  command-line-arguments    2.298s   10000
# 31  command-line-arguments    2.299s   10000
# 32  command-line-arguments    2.283s   10000
# 33  command-line-arguments    2.836s  100000
# 34  command-line-arguments    1.806s  100000
# 35  command-line-arguments    2.783s  100000
# 36  command-line-arguments    2.720s  100000
# 37  command-line-arguments    2.719s  100000
# 38  command-line-arguments    2.782s  100000
# 39  command-line-arguments    2.786s  100000
# 40  command-line-arguments    2.789s  100000
# 41  command-line-arguments    2.707s  100000
# 42  command-line-arguments    2.800s  100000
# 43  command-line-arguments    1.859s  100000

# %%
# dados_hm.num = pd.to_numeric(dados_hm.num)

# %%
dados_hm['exec_time'] = pd.to_numeric(dados_hm['exec_time'].str[:-1], downcast='float')

# %%
dados_hm_filtered = dados_hm.filter(['exec_time', 'num'])
dados_hm_filtered['num'] = dados_hm_filtered['num'].astype(np.str)
dados_hm_filtered['num']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-8dcca1f240f4> in <module>
#       1 dados_hm_filtered = dados_hm.filter(['exec_time', 'num'])
# ----> 2 dados_hm_filtered['num'] = pd.to_string(dados_hm_filtered['num'])
#       3 dados_hm_filtered['num']
#
# AttributeError: module 'pandas' has no attribute 'to_string'

# %%
fig, gph = plt.subplots(figsize=(10,7))

gph = sns.stripplot(x='exec_time', y='num', data=dados_hm_filtered.sort_values(by='num', ascending=True), s=8, lw=1, jitter=True, linewidth=1)

# gph.set_title('Custo por aluno das Universidades Federais \ndo Brasil em 2016 x Conceito do Enade por curso', fontsize=20)

gph.set_ylabel('Faixa de renda familiar', fontsize=15)

gph.set_xlabel('Nota geral do aluno no ENADE', fontsize=15)

plt.show()
